# %%
import pandas as pd # Importing libraries 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna() # removing the missing and null values
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data.dropna(inplace=True)#remove all rows of missing values and modify in place without creating new one.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  int64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
data.describe()# for the statistics numerical column
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.hist(bins=50, figsize=(20,15))# histogram shows the frequency of values, helps to identify patterns and outlires.
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
data.plot(kind="scatter", x= "longitude", y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
data.plot(kind="scatter", x= "longitude", y="latitude", alpha =0.2,)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
data.plot(kind="scatter", x= "longitude", y="latitude", alpha =0.3, s=data["population"]/200, label = "population", c="median_house_value", cmap= plt.get_cmap("jet"))
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
#corr_matrix = data.corr()
#corr_matrix["median_house_value"].sort_values(ascending=False) #ValueError: could not convert string to float: 'NEAR BAY'

# %%
data_cat = data.select_dtypes(object)# seperating categorical data
data_num = data.select_dtypes(["float64","int64"])# seperating numerical data

# %%
data_cat.head()
# Out:
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY

# %%
data_cat["ocean_proximity"].value_counts()# counting the categorical values
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
Ocean_data = pd.get_dummies(data_cat["ocean_proximity"])

# %%
Ocean_data.head()
# Out:
#    <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0      False   False   False      True       False
# 1      False   False   False      True       False
# 2      False   False   False      True       False
# 3      False   False   False      True       False
# 4      False   False   False      True       False

# %%
from sklearn.preprocessing import LabelEncoder # for label encoding  categorical data/ converting into numerical form.

# %%
le = LabelEncoder()

# %%
le.fit_transform(data_cat["ocean_proximity"])
# Out:
# array([3, 3, 3, ..., 1, 1, 1])

# %%
for col in data_cat:
    le = LabelEncoder()
    data_cat[col] = le.fit_transform(data_cat[col])

# %%
data_cat.head()
# Out:
#    ocean_proximity
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3

# %%
data_new = pd.concat([data_num,data_cat],axis=1)# merging the categorical( now numeric) and numerical data.

# %%
data_new
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data_new.corr() # for correlation
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
# ocean_proximity     -0.289530  0.200801            0.112330    -0.015363
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data_new.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
corr_matrix = data_new.corr()# correlation matrix.
corr_matrix["median_house_value"].sort_values(ascending=False) # how the median_house_value is correlated with other variables.
# Out:
# median_house_value    1.000000
# median_income         0.688355
# total_rooms           0.133294
# housing_median_age    0.106432
# ocean_proximity       0.080488
# households            0.064894
# total_bedrooms        0.049686
# population           -0.025300
# longitude            -0.045398
# latitude             -0.144638
# Name: median_house_value, dtype: float64

# %%
columns_to_check = [ 'longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 
                    'households', 'median_income', 'median_house_value', 'ocean_proximity']

# %%
from scipy.stats import zscore # Z- score for outlier 
data_new_zscore = data_new[columns_to_check].apply(zscore)
threshold = 3

# %%
outliers = (np.abs(data_new_zscore) > threshold).any(axis=1)

# %%
New_data = data_new[~outliers]

# %%
New_data.to_csv('New_data.csv', index=False)# new data set after removing outliers

# %%
print(f"Outliers removed: {outliers.sum()} rows")
# Out:
# Outliers removed: 884 rows

# %%
New_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
from sklearn.model_selection import train_test_split# importing train_test_split for model evaluation of subset set of data

x = New_data.drop(['median_house_value'], axis=1)
y = New_data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 19549, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size =0.2)# splitting data for train and test purpose.

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2361     -119.53     36.78                  20         2822           479.0
# 17562    -121.89     37.32                  41          977           265.0
# 16023    -122.45     37.73                  52         2510           438.0
# 6788     -118.15     34.09                  52         2203           430.0
# 19796    -123.18     40.58                  18         1451           278.0
# ...          ...       ...                 ...          ...             ...
# 8967     -118.40     34.00                  37         1534           258.0
# 8023     -118.12     33.84                  37         2706           462.0
# 17932    -121.94     37.35                  52          906           227.0
# 2841     -118.98     35.40                  34          813           171.0
# 18239    -122.10     37.40                  23          514           210.0
#
# ...

# %%
y_train
# Out:
# 2361     136900
# 17562    184800
# 16023    335100
# 6788     225800
# 19796     73700
#           ...
# 8967     336000
# 8023     220000
# 17932    231600
# 2841      69800
# 18239    181300
# Name: median_house_value, Length: 15639, dtype: int64

# %%
from sklearn.linear_model import LinearRegression # Importing LinearRegression for fitting a linear model for prediction. 
clf = LinearRegression() # creating a linear regression model object

# %%
clf.fit(x_train, y_train) # trains the x and y
# Out:
# LinearRegression()

# %%
clf.predict(x_test) # generate prediction based on the trained model.
# Out:
# array([144376.95808029,  56375.90387035, 164782.42921788, ...,
#        107446.30505505, 129519.68377981, 225904.76859588])

# %%
y_test
# Out:
# 19023    129500
# 12583     78300
# 16581    147600
# 4904     118800
# 12053    113000
#           ...
# 2146      64700
# 19164    160200
# 4429     154200
# 3007      65000
# 14693    129300
# Name: median_house_value, Length: 3910, dtype: int64

# %%
clf.score(x_test, y_test)# model accuracy of the test data
# Out:
# 0.6169956267304016

# %%
from sklearn.ensemble import RandomForestRegressor # RandomForestRegressor is for averaging to imporve the predictive accuracy and control over-fitting
forest = RandomForestRegressor()
forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.7947469574997251

# %%
## we found randomforestregressor with the accuracy of 0.7947 (79.47%) is better than linear regression with accuracy of 0.6169(61.69%).
